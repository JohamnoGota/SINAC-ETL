# %% [markdown]
# # Exploratory Data Analysis (EDA) for the SINAC database
#
# The Database is divided into as far as I can tell 3 distinct time periods.
#
# - 2008 - 2014
# - 2014 - 2019
# - 2020 - 2024
#
# A separate task of EDA is required for each time period to properly analyze.
# Either way a common star schema seems to be common to every time period. a central facts table with over 50 columns for the births and many dimension tables for each columns, the facts table has only foreign keys and dates, no measures as far as I can tell.

# %% [markdown]
# ## General preparation for EDA

# %%
#imports 

import pandas as pd
import time

# %%
def timeit(method):
    """
    Timeit Decorator 
        Description: adds timekeeping functionality for any function, output is not modified and time is printed to terminal  
    """
    # inner function that will be timed
    def timed(*args, **kwargs):
        ts = time.time()
        result = method(*args, **kwargs)
        te = time.time()
        # rounding to n decimals and printing timed output 
        timed = round((te - ts), 5)
        print(f"{method.__name__} took {timed} seconds to run")
        return result
    return timed

# %% [markdown]
# ## 2008 - 2014 period

# %% [markdown]
# ## 2015 - 2019
#
# What's of interest here are the columns mainly, any kind of processing of the rows I think should be done during the silver layer when we can work with parquets.

# %%
df = pd.read_csv("../Datasets/sinac2015DatosAbiertos.csv") # takes 10.2 seconds to read
# Out:
# /var/folders/z1/68dj1nsn37j6r4hvztw0rhqr0000gq/T/ipykernel_80514/3487507447.py:1: DtypeWarning: Columns (0: madre_se_considera_indigena, 1: madre_habla_lengua_indigena, 2: lengua_indigena_hablada, 3: clues_certifico, 4: tipo_formato) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../Datasets/sinac2015DatosAbiertos.csv")

# %%
base_columns = []
for index,column in enumerate(df.columns):
    print(index, column)
    base_columns.append([index, column])
# Out:
# 0 edo_captura
# 1 edo_nac_madre
# 2 mpo_nac_madre
# 3 fecha_nac_madre
# 4 edad_madre
# 5 madre_se_considera_indigena
# 6 madre_habla_lengua_indigena
# 7 lengua_indigena_hablada
# 8 estado_conyugal
# 9 entidad_residencia_madre
# 10 municipio_residencia_madre
# 11 localidad_residencia_madre
# 12 numero_embarazos
# 13 hijos_nacidos_muertos
# 14 hijos_nacidos_vivos
# 15 hijos_sobrevivientes
# 16 el_hijo_anterior_nacio
# 17 vive_aun_hijo_anterior
# 18 orden_nacimiento
# 19 recibio_atencion_prenatal
# 20 trimestre_recibio_primera_consulta
# 21 total_consultas_recibidas
# 22 madre_sobrevivio_al_parto
# 23 afiliacion_serv_salud
# 24 escolaridad_madre
# 25 ocupacion_habitual_madre
# 26 trabaja_actualmente
# 27 fecha_nacimiento_nac_vivo
# 28 hora_nacimiento_nac_vivo
# 29 sexo_nac_vivo
# 30 semanas_gestacion_nac_vivo
# 31 talla_nac_vivo
# 32 peso_nac_vivo
# 33 valoracion_apgar_nac_vivo
# 34 valoracion_silverman_nac_vivo
# 35 recibio_vacuna_bcg
# 36 recibio_vacuna_hep_b
# 37 recibio_vit_a
# ...

# %%
base_columns
# Out:
# [[0, 'edo_captura'],
#  [1, 'edo_nac_madre'],
#  [2, 'mpo_nac_madre'],
#  [3, 'fecha_nac_madre'],
#  [4, 'edad_madre'],
#  [5, 'madre_se_considera_indigena'],
#  [6, 'madre_habla_lengua_indigena'],
#  [7, 'lengua_indigena_hablada'],
#  [8, 'estado_conyugal'],
#  [9, 'entidad_residencia_madre'],
#  [10, 'municipio_residencia_madre'],
#  [11, 'localidad_residencia_madre'],
#  [12, 'numero_embarazos'],
#  [13, 'hijos_nacidos_muertos'],
#  [14, 'hijos_nacidos_vivos'],
#  [15, 'hijos_sobrevivientes'],
#  [16, 'el_hijo_anterior_nacio'],
#  [17, 'vive_aun_hijo_anterior'],
#  [18, 'orden_nacimiento'],
#  [19, 'recibio_atencion_prenatal'],
#  [20, 'trimestre_recibio_primera_consulta'],
#  [21, 'total_consultas_recibidas'],
#  [22, 'madre_sobrevivio_al_parto'],
#  [23, 'afiliacion_serv_salud'],
#  [24, 'escolaridad_madre'],
#  [25, 'ocupacion_habitual_madre'],
#  [26, 'trabaja_actualmente'],
#  [27, 'fecha_nacimiento_nac_vivo'],
#  [28, 'hora_nacimiento_nac_vivo'],
#  [29, 'sexo_nac_vivo'],
# ...

# %% [markdown]
# ### Checking column consistency
# Over every file check the name and number of columns are consistent.

# %%
def compareColumns(base : list[list], )

# %% [markdown]
# ## 2020 - 2023 Period
